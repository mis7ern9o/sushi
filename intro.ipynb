# %%
from IPython.display import Image
Image(filename='./img/code_girl.png', width=400, embed=True)

# %%
print('oui')
# Out:
# oui

# %% [markdown]
# "Ne vous inquiétez pas pour vos difficultés en mathématiques, les miennes sont encore plus grandes" - Albert Einstein
# "Un langage qui n'affecte pas votre manière de penser la programmation ne vaut pas la peine d'être connu" - Alan Perlis

# %% [markdown]
# # Let's code !

# %% [markdown]
# # Reference biblio
#
# ## Introduction
# - [InfoRef - apprendre_python](https://inforef.be/swi/download/apprendre_python.pdf)
# - [base Python](https://courspython.com/bases-python.html)
#
# ## ...

# %% [markdown]
# # Basics

# %% [markdown]
# ## challenges
# ### Challenge 001
# creation d'une invite utilisateur

# %%
firstname = input("Please enter your firstname: ")
print("Hello",firstname)
# Out:
# Please enter your firstname:  emy
# Hello emy

# %% [markdown]
# ### Challenge 002
# creation de 2 invites utilisateurs

# %%
firtname = input("Please enter your firstname: ")
lastname = input("Please enter your lastname: ")
print("Hello", firstname,lastname)
# Out:
# Please enter your firstname:  emy
# Please enter your lastname:  ledirach
# Hello emy ledirach

# %% [markdown]
# ### Challenge 003
# print sur plusieures lignes

# %%
print("Quel est la couleur du cheval blanc de Henri IV:\nBlanc! ")
# Out:
# Quel est la couleur du cheval blanc de Henri IV:
# Blanc!

# %% [markdown]
# ### Challenge 004
# creation de 2 invites utilisateur avec des valeurs numeriques

# %%
emy = int(input("what is your first number?: "))
erwan = int(input("what is my second number?: "))
total = emy + erwan
print("the answer is ",total)
# Out:
# what is your first number?:  2
# what is my second number?:  3
# the answer is  5

# %% [markdown]
# ### Challenge 005
# creation de 3 input box avc des valeurs numériques calculées

# %%
vanille = int(input("what is your first number?: "))
chocolat = int(input("what is your second number?: "))
fraise = int(input("what is your third number?: "))
total = (vanille + chocolat) * fraise
print("the answer is ",total)
# Out:
# what is your first number?:  2
# what is your second number?:  3
# what is your third number?:  2
# the answer is  10
